# %%
# General imports
import numpy as np
import pandas as pd
import os, sys, gc, warnings, random, datetime

from sklearn import metrics
from sklearn.model_selection import train_test_split, KFold, GroupKFold
from sklearn.preprocessing import LabelEncoder

from tqdm import tqdm

import math
warnings.filterwarnings('ignore')

# %%
## Seeder
# :seed to make all processes deterministic     # type: int
def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

# %%
## Memory Reducer
# :df pandas dataframe to reduce size             # type: pd.DataFrame()
# :verbose                                        # type: bool
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
########################### Model
import lightgbm as lgb

def make_predictions(tr_df, tt_df, features_columns, target, lgb_params, NFOLDS=2):
    
    folds = GroupKFold(n_splits=NFOLDS)

    X,y = tr_df[features_columns], tr_df[target]    
    P,P_y = tt_df[features_columns], tt_df[target]  
    split_groups = tr_df['DT_M']

    tt_df = tt_df[['TransactionID',target]]    
    predictions = np.zeros(len(tt_df))
    oof = np.zeros(len(tr_df))
    
    for fold_, (trn_idx, val_idx) in enumerate(folds.split(X, y, groups=split_groups)):
        print('Fold:',fold_)
        tr_x, tr_y = X.iloc[trn_idx,:], y[trn_idx]
        vl_x, vl_y = X.iloc[val_idx,:], y[val_idx]
            
        print(len(tr_x),len(vl_x))
        tr_data = lgb.Dataset(tr_x, label=tr_y)
        vl_data = lgb.Dataset(vl_x, label=vl_y)  

        estimator = lgb.train(
            lgb_params,
            tr_data,
            valid_sets = [tr_data, vl_data],
            verbose_eval = 200,
        )   
        
        pp_p = estimator.predict(P)
        predictions += pp_p/NFOLDS
        
        oof_preds = estimator.predict(vl_x)
        oof[val_idx] = (oof_preds - oof_preds.min())/(oof_preds.max() - oof_preds.min())

        if LOCAL_TEST:
            feature_imp = pd.DataFrame(sorted(zip(estimator.feature_importance(),X.columns)), columns=['Value','Feature'])
            print(feature_imp)
        
        del tr_x, tr_y, vl_x, vl_y, tr_data, vl_data
        gc.collect()
        
    tt_df['prediction'] = predictions
    print('OOF AUC:', metrics.roc_auc_score(y, oof))
#     if LOCAL_TEST:
#         print('Holdout AUC:', metrics.roc_auc_score(tt_df[TARGET], tt_df['prediction']))
    
    return tt_df
## -------------------

# %%
for a  in test_df['isFraud']:
    if a  is not 0:
        print(a)

# %%
########################### Vars
#################################################################################
SEED = 42
seed_everything(SEED)
LOCAL_TEST = True
TARGET = 'isFraud'
START_DATE = datetime.datetime.strptime('2017-11-30', '%Y-%m-%d')

# %%
########################### Model params
lgb_params = {
                    'objective':'binary',
                    'boosting_type':'gbdt',
                    'metric':'auc',
                    'n_jobs':-1,
                    'learning_rate':0.01,
                    'num_leaves': 2**8,
                    'max_depth':-1,
                    'tree_learner':'serial',
                    'colsample_bytree': 0.5,
                    'subsample_freq':1,
                    'subsample':0.7,
                    'n_estimators':800,
                    'max_bin':255,
                    'verbose':-1,
                    'seed': SEED,
                    'early_stopping_rounds':100, 
                }

# %%
########################### DATA LOAD
#################################################################################
print('Load Data')

if LOCAL_TEST:
#     train_df = pd.read_pickle('../Data/ieee-fe-for-local-test/train_df.pkl')
#     test_df = pd.read_pickle('../Data/ieee-fe-for-local-test/test_df.pkl') 
    train_df = pd.read_pickle('../Data/train_df.pkl')
    test_df = pd.read_pickle('../Data/test_df.pkl') 
# else:
#     train_df = pd.read_pickle('../Data/ieee-fe-with-some-eda/train_df.pkl')
#     test_df = pd.read_pickle('../Data/ieee-fe-with-some-eda/test_df.pkl')
    
remove_features = pd.read_pickle('../Data/remove_features.pkl')
remove_features = list(remove_features['features_to_remove'].values)
print('Shape control:', train_df.shape, test_df.shape)
# Out:
# Load Data
# Shape control: (590540, 791) (506691, 791)

# %%
########################### Final features list
features_columns = [col for col in list(train_df) if col not in remove_features]

########################### Final Minification
## I don't like this part as it changes float numbers
## small change but change.
## To be able to train lgbm without 
## minification we need to do some changes on model
## we will do it later.
if not LOCAL_TEST:
    train_df = reduce_mem_usage(train_df)
    test_df  = reduce_mem_usage(test_df)

# %%
########################### Model Train
if LOCAL_TEST:
    lgb_params['learning_rate'] = 0.01
    lgb_params['n_estimators'] = 10000
    lgb_params['early_stopping_rounds'] = 100
    test_predictions = make_predictions(train_df, test_df, features_columns, TARGET, lgb_params, NFOLDS=4)
else:
    lgb_params['learning_rate'] = 0.007
    lgb_params['n_estimators'] = 10000
    lgb_params['early_stopping_rounds'] = 100    
    test_predictions = make_predictions(train_df, test_df, features_columns, TARGET, lgb_params, NFOLDS=6)
# Out:
# Fold: 0
# 453219 137321
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.976001	valid_1's auc: 0.891099
# [400]	training's auc: 0.995	valid_1's auc: 0.905092
# [600]	training's auc: 0.998932	valid_1's auc: 0.909981
# [800]	training's auc: 0.999767	valid_1's auc: 0.913811
# [1000]	training's auc: 0.999951	valid_1's auc: 0.915939
# [1200]	training's auc: 0.999992	valid_1's auc: 0.917657
# [1400]	training's auc: 0.999999	valid_1's auc: 0.918488
# Early stopping, best iteration is:
# [1381]	training's auc: 0.999999	valid_1's auc: 0.91859
#      Value                        Feature
# 0        0                      D9_not_na
# 1        0                           V107
# 2        0                           V117
# 3        0                           V119
# 4        0                           V120
# 5        0                           V240
# 6        0                            V27
# 7        0                            V28
# 8        0                           V305
# 9        0                            V41
# 10       0                            V68
# 11       0                            V88
# 12       0                            V89
# 13       0                          id_27
# 14       0                    is_december
# 15       1                           V122
# 16       1                           V141
# 17       1                            V21
# 18       1                           V241
# 19       1                            V65
# 20       2                             V1
# 21       2                           V104
# 22       2                           V113
# 23       2                           V142
# 24       2                            V22
# 25       2                          id_22
# 26       2                          id_35
# 27       3                           V118
# 28       3                            V14
# 29       3                           V196
# ..     ...                            ...
# 742   1716                    uid4_D9_std
# 743   1720             D10_DT_W_std_score
# 744   1733                   uid5_D8_mean
# 745   1738    TransactionAmt_DT_W_min_max
# 746   1757             D15_DT_W_std_score
# 747   1776                   uid3_D9_mean
# 748   1799                   product_type
# 749   1802           card5_DT_D_hour_dist
# 750   1814                          addr1
# 751   1816                   uid4_D8_mean
# 752   1838                   uid3_D8_mean
# 753   1881                   uid4_D3_mean
# 754   1882                   uid4_D2_mean
# 755   1891                   uid4_D5_mean
# 756   1968              D8_DT_D_std_score
# 757   1972           card3_DT_D_hour_dist
# 758   1978                    uid4_D3_std
# 759   2005                    uid4_D5_std
# 760   2011  TransactionAmt_DT_D_std_score
# 761   2053                    uid4_D2_std
# 762   2074    TransactionAmt_DT_D_min_max
# 763   2110             D10_DT_D_std_score
# 764   2111                   uid4_D9_mean
# 765   2142              D4_DT_D_std_score
# 766   2146              product_type_DT_M
# 767   2156        uid4_TransactionAmt_std
# 768   2169                          card1
# 769   2221             D15_DT_D_std_score
# 770   2282              product_type_DT_W
# 771   2620              product_type_DT_D
#
# [772 rows x 2 columns]
# Fold: 1
# 488908 101632
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.976813	valid_1's auc: 0.926885
# [400]	training's auc: 0.995152	valid_1's auc: 0.939853
# [600]	training's auc: 0.999012	valid_1's auc: 0.944143
# [800]	training's auc: 0.999777	valid_1's auc: 0.945935
# [1000]	training's auc: 0.999953	valid_1's auc: 0.946791
# [1200]	training's auc: 0.999992	valid_1's auc: 0.947031
# Early stopping, best iteration is:
# [1271]	training's auc: 0.999996	valid_1's auc: 0.947143
#      Value                        Feature
# 0        0                           V107
# 1        0                           V117
# 2        0                           V118
# 3        0                           V120
# 4        0                           V122
# 5        0                           V240
# 6        0                           V241
# 7        0                            V27
# 8        0                            V28
# 9        0                           V305
# 10       0                            V65
# 11       0                            V68
# 12       0                            V88
# 13       0                            V89
# 14       0                          id_27
# 15       1                           V119
# 16       1                            V14
# 17       1                            V98
# 18       2                      D9_not_na
# 19       2                             V1
# 20       2                           V142
# 21       2                            V21
# 22       2                           V284
# 23       2                           V325
# 24       2                            V41
# 25       3                D8_not_same_day
# 26       3                           V113
# 27       3                           V269
# 28       3                           V328
# 29       3                          id_22
# ..     ...                            ...
# 742   1583                  P_emaildomain
# 743   1583                    uid4_D5_std
# 744   1591                   uid5_D9_mean
# 745   1598                   uid5_D8_mean
# 746   1601                   uid3_D8_mean
# 747   1613    TransactionAmt_DT_W_min_max
# 748   1615             D15_DT_W_std_score
# 749   1617    TransactionAmt_DT_D_min_max
# 750   1621                          addr1
# 751   1649  TransactionAmt_DT_W_std_score
# 752   1651           card3_DT_D_hour_dist
# 753   1665                    uid3_D9_std
# 754   1687                   uid4_D5_mean
# 755   1690                          id_02
# 756   1692              D4_DT_D_std_score
# 757   1701                   uid3_D9_mean
# 758   1704                   uid4_D8_mean
# 759   1733                   uid4_D2_mean
# 760   1734                   uid4_D9_mean
# 761   1763              product_type_DT_M
# 762   1779                   uid4_D3_mean
# 763   1830                    uid4_D2_std
# 764   1835        uid4_TransactionAmt_std
# 765   1890             D15_DT_D_std_score
# 766   1891              D8_DT_D_std_score
# 767   2043  TransactionAmt_DT_D_std_score
# 768   2057              product_type_DT_W
# 769   2117                          card1
# 770   2187             D10_DT_D_std_score
# 771   2598              product_type_DT_D
#
# [772 rows x 2 columns]
# Fold: 2
# 414300 176240
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.978696	valid_1's auc: 0.928295
# [400]	training's auc: 0.996474	valid_1's auc: 0.942489
# [600]	training's auc: 0.999408	valid_1's auc: 0.946891
# [800]	training's auc: 0.999892	valid_1's auc: 0.948223
# [1000]	training's auc: 0.999983	valid_1's auc: 0.948922
# [1200]	training's auc: 0.999998	valid_1's auc: 0.94932
# Early stopping, best iteration is:
# [1254]	training's auc: 0.999998	valid_1's auc: 0.949377
#      Value                        Feature
# 0        0                             V1
# 1        0                           V107
# 2        0                           V113
# 3        0                            V14
# 4        0                           V241
# 5        0                            V27
# 6        0                            V28
# 7        0                           V305
# 8        0                            V65
# 9        0                            V68
# 10       0                            V88
# 11       0                            V89
# 12       0                          id_27
# 13       1                           V117
# 14       1                           V240
# 15       1                           V269
# 16       1                           V325
# 17       1                           V328
# 18       1                            V41
# 19       1                          id_35
# 20       2                D8_not_same_day
# 21       2                      D9_not_na
# 22       2                           V122
# 23       2                           V157
# 24       2                            V21
# 25       2                           V302
# 26       3                           V114
# 27       3                           V142
# 28       4                           V101
# 29       4                           V120
# ..     ...                            ...
# 742   1558    TransactionAmt_DT_W_min_max
# 743   1563           card5_DT_D_hour_dist
# 744   1580                   product_type
# 745   1583                    uid3_D9_std
# 746   1585    TransactionAmt_DT_D_min_max
# 747   1586                   uid5_D9_mean
# 748   1596                          addr1
# 749   1613      card3_DT_D_hour_dist_best
# 750   1617  TransactionAmt_DT_W_std_score
# 751   1623                    uid4_D5_std
# 752   1627                          id_02
# 753   1649                   uid4_D8_mean
# 754   1687                   uid4_D5_mean
# 755   1699                   uid5_D8_mean
# 756   1707                   uid4_D9_mean
# 757   1715              product_type_DT_M
# 758   1747                   uid3_D9_mean
# 759   1792                   uid4_D3_mean
# 760   1802           card3_DT_D_hour_dist
# 761   1828                   uid4_D2_mean
# 762   1841              D4_DT_D_std_score
# 763   1841        uid4_TransactionAmt_std
# 764   1860                    uid4_D2_std
# 765   1903  TransactionAmt_DT_D_std_score
# 766   1916             D15_DT_D_std_score
# 767   1923              D8_DT_D_std_score
# 768   2057             D10_DT_D_std_score
# 769   2091              product_type_DT_W
# 770   2101                          card1
# 771   2454              product_type_DT_D
#
# [772 rows x 2 columns]
# Fold: 3
# 415193 175347
# Training until validation scores don't improve for 100 rounds.
# [200]	training's auc: 0.979669	valid_1's auc: 0.929887
# [400]	training's auc: 0.996587	valid_1's auc: 0.941481
# [600]	training's auc: 0.999423	valid_1's auc: 0.945125
# [800]	training's auc: 0.999895	valid_1's auc: 0.946275
# [1000]	training's auc: 0.999984	valid_1's auc: 0.94661
# [1200]	training's auc: 0.999998	valid_1's auc: 0.946658
# Early stopping, best iteration is:
# [1133]	training's auc: 0.999996	valid_1's auc: 0.946752
#      Value                        Feature
# 0        0                           V107
# 1        0                           V117
# 2        0                           V118
# 3        0                           V119
# 4        0                           V122
# 5        0                           V240
# 6        0                           V241
# 7        0                            V27
# 8        0                            V28
# 9        0                           V305
# 10       0                           V325
# 11       0                           V334
# 12       0                            V68
# 13       0                            V88
# 14       0                            V89
# 15       0                          id_27
# 16       1                           V120
# 17       1                            V14
# 18       1                           V269
# 19       1                            V41
# 20       1                            V65
# 21       1                          id_35
# 22       3                      D9_not_na
# 23       3                             M1
# 24       3                             V1
# 25       3                           V114
# 26       3                           V121
# 27       3                           V142
# 28       3                            V50
# 29       4                           V113
# ..     ...                            ...
# 742   1409  TransactionAmt_DT_W_std_score
# 743   1410                    uid4_D5_std
# 744   1420                   uid4_D8_mean
# 745   1423    TransactionAmt_DT_W_min_max
# 746   1452                   uid3_D8_mean
# 747   1478                   uid3_D9_mean
# 748   1479           card3_DT_D_hour_dist
# 749   1481           card5_DT_D_hour_dist
# 750   1509                            C13
# 751   1527                   uid4_D9_mean
# 752   1527                   uid5_D9_mean
# 753   1534                          addr1
# 754   1534                   uid4_D2_mean
# 755   1538              D4_DT_D_std_score
# 756   1551                          id_02
# 757   1558                   uid5_D8_mean
# 758   1567                    uid3_D9_std
# 759   1610    TransactionAmt_DT_D_min_max
# 760   1638        uid4_TransactionAmt_std
# 761   1653                   uid4_D5_mean
# 762   1659              product_type_DT_M
# 763   1662                   uid4_D3_mean
# 764   1669             D15_DT_D_std_score
# 765   1709  TransactionAmt_DT_D_std_score
# 766   1729                    uid4_D2_std
# 767   1758              D8_DT_D_std_score
# 768   1868                          card1
# 769   1892              product_type_DT_W
# 770   2005             D10_DT_D_std_score
# 771   2337              product_type_DT_D
#
# [772 rows x 2 columns]
# OOF AUC: 0.9426270490973361
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4a3301b420ff> in <module>()
#       4     lgb_params['n_estimators'] = 10000
#       5     lgb_params['early_stopping_rounds'] = 100
# ----> 6     test_predictions = make_predictions(train_df, test_df, features_columns, TARGET, lgb_params, NFOLDS=4)
#       7 else:
#       8     lgb_params['learning_rate'] = 0.007
#
# <ipython-input-4-9f80b6845434> in make_predictions(tr_df, tt_df, features_columns, target, lgb_params, NFOLDS)
#      46     print('OOF AUC:', metrics.roc_auc_score(y, oof))
#      47     if LOCAL_TEST:
# ---> 48         print('Holdout AUC:', metrics.roc_auc_score(tt_df[TARGET], tt_df['prediction']))
#      49
#      50     return tt_df
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     354     return _average_binary_score(
#     355         _binary_roc_auc_score, y_true, y_score, average,
# --> 356         sample_weight=sample_weight)
#     357
#     358
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     322     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     323         if len(np.unique(y_true)) != 2:
# --> 324             raise ValueError("Only one class present in y_true. ROC AUC score "
#     325                              "is not defined in that case.")
#     326
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
########################### Export
if not LOCAL_TEST:
    test_predictions['isFraud'] = test_predictions['prediction']
    test_predictions[['TransactionID','isFraud']].to_csv('submission.csv', index=False)

# %%
from sklearn.metrics import roc_auc_score
accuracy = roc_auc_score(test_df, test_predictions)
print("AUC: %.2f%%" % (accuracy * 100.0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-efc31dddda29> in <module>()
#       1 from sklearn.metrics import roc_auc_score
# ----> 2 accuracy = roc_auc_score(test_df, test_predictions)
#       3 print("AUC: %.2f%%" % (accuracy * 100.0))
#
# NameError: name 'test_predictions' is not defined
